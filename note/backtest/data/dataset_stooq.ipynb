# %% [markdown]
# # Download and store STOOQ data
# [ref](https://github.com/stefan-jansen/machine-learning-for-trading/blob/main/data/create_stooq_data.ipynb)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Imports & Settings

# %%
from pathlib import Path
import requests
from io import BytesIO
from zipfile import ZipFile, BadZipFile

import numpy as np
import pandas as pd
import pandas_datareader.data as web
from sklearn.datasets import fetch_openml

pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# ## Set Data Store path

# %%
STORAGE_PATH = "E:"

# %%
DATA_STORE = Path('assets.h5')
try:
    DATA_STORE = STORAGE_PATH/ DATA_STORE
except:
    pass
print(DATA_STORE.cwd())
# Out:
# C:\Users\taest\Documents\github\research_market_finance\MLFT\data

# %%
stooq_path = Path("stooq")
try:
    stooq_path = STORAGE_PATH/stooq_path
    print(stooq_path)
except:
    pass
if not stooq_path.exists():
    stooq_path.mkdir()
print(stooq_path.cwd())
# Out:
# E:stooq
# C:\Users\taest\Documents\github\research_market_finance\MLFT\data

# %% [markdown]
# ### Stooq Historical Market Data
#
# - 여기서 파일을 받아 `stooq_path'에 저장한다
# [url](https://stooq.com/db/h/)

# %%
def get_price_data(market='us'):
    file_path = f'd_{market}_txt.zip'
    zip_path = stooq_path/file_path
    with ZipFile(zip_path) as zip_file:
        for i, file in enumerate(zip_file.namelist()):
            if not file.endswith('.txt'):
                continue
            local_file = stooq_path / file
            local_file.parent.mkdir(parents=True, exist_ok=True)
            with local_file.open('wb') as output:
                for line in zip_file.open(file).readlines():
                    output.write(line)

# %%
for market in ['us', 'jp', 'macro','hk', 'world']:
    get_price_data(market=market)

# %% [markdown]
# ### Add symbols

# %% [markdown]
# - 아래 링크에 접속하여 meta 파일을 만들어야 함.
#  `파일명: 69.csv` https://stooq.com/db/l/?g=69
# - meta 목록 확인: https://stooq.com/db/

# %%
meta_path = stooq_path/"data/meta"
if not meta_path.exists():
    meta_path.mkdir()

# %%
metadata_dict = {
    ('jp', 'tse etfs'): 34,
    ('jp', 'tse stocks'): 32,
    ('jp', 'macro'): 46,
    ('us', 'nasdaq etfs'): 69,
    ('us', 'nasdaq stocks'): 27,
    ('us', 'nyse etfs'): 70,
    ('us', 'nyse stocks'): 28,
    ('us', 'nysemkt stocks'): 26,
    ('us', 'macro'): 50,
    ('kr', 'macro'): 87,
    ('cn', 'macro'): 42,
    ('world', 'bonds'): 53,
    ('world', 'money market'): 39,
    ('world', 'crypto'): 59,
    ('world', 'other_fx'): 52,
    ('world', 'index'): 1,
    # ('world', 'stooq_stock_idx'): 25,
    ('world', 'major_fx'): 3,
    # ('hk','hk cbbcs'): 79,
    ('hk','hk etfs'): 74,
    # ('hk','hk corporate bonds'): 77,
    # ('hk','hk reits'): 80,
    # ('hk','hk drs'): 75,
    ('hk','hk stocks'): 73,
    # ('hk','hk dws'): 78,
    # ('hk','hk treasury bonds'): 76,
}

# %%
for (market, asset_class), code in metadata_dict.items():
    df = pd.read_csv(meta_path/f'{code}.csv', sep='        ').apply(lambda x: x.str.strip())
    df.columns = ['ticker', 'name']
    df = df.drop_duplicates('ticker').dropna()
    print(market, asset_class, f'# tickers: {df.shape[0]:,.0f}')
    path = stooq_path / 'tickers' / market
    if not path.exists():
        path.mkdir(parents=True)
    df.to_csv(path / f'{asset_class}.csv', index=False)
# Out:
# jp tse etfs # tickers: 392
# jp tse stocks # tickers: 3,941
# jp macro # tickers: 31
# us nasdaq etfs # tickers: 356
# us nasdaq stocks # tickers: 4,669
# us nyse etfs # tickers: 2,104
# us nyse stocks # tickers: 3,554
# us nysemkt stocks # tickers: 319
# us macro # tickers: 79
# kr macro # tickers: 22
# cn macro # tickers: 11
# world bonds # tickers: 125
# world money market # tickers: 44
# world crypto # tickers: 271
# world other_fx # tickers: 1,840
# world index # tickers: 61
# world major_fx # tickers: 66
# hk hk etfs # tickers: 191
# hk hk stocks # tickers: 2,555

# %% [markdown]
# ## Store price data in HDF5 format

# %%
def get_stooq_prices_and_tickers(frequency='daily',
                                 market='us',
                                 asset_class='nasdaq etfs'):
    prices = []
    
    tickers = (pd.read_csv(stooq_path / 'tickers' / market / f'{asset_class}.csv'))

    if frequency in ['5 min', 'hourly']:
        parse_dates = [['date', 'time']]
        date_label = 'date_time'
    else:
        parse_dates = ['date']
        date_label = 'date'
    names = ['ticker', 'freq', 'date', 'time', 
             'open', 'high', 'low', 'close','volume', 'openint']
    
    usecols = ['ticker', 'open', 'high', 'low', 'close', 'volume'] + parse_dates
    path = stooq_path / 'data' / frequency / market / asset_class
    print(path.as_posix())
    files = path.glob('**/*.txt')
    for i, file in enumerate(files, 1):
        if i % 500 == 0:
            print(i)
        if file.stem not in set(tickers.ticker.str.lower()):
            print(file.stem, 'not available')
            file.unlink()
        else:
            try:
                df = (pd.read_csv(
                    file,
                    names=names,
                    usecols=usecols,
                    header=0,
                    parse_dates=parse_dates))
                prices.append(df)
            except pd.errors.EmptyDataError:
                print('\tdata missing', file.stem)
                file.unlink()

    prices = (pd.concat(prices, ignore_index=True)
              .rename(columns=str.lower)
              .set_index(['ticker', date_label])
              .apply(lambda x: pd.to_numeric(x, errors='coerce')))
    return prices, tickers

# %%
# load some Japanese and all US assets for 2000-2019
markets = {'jp': ['tse stocks'],
           'us': ['nasdaq etfs', 'nasdaq stocks', 'nyse etfs', 'nyse stocks', 'nysemkt stocks']
          }
frequency = 'daily'

idx = pd.IndexSlice
for market, asset_classes in markets.items():
    for asset_class in asset_classes:
        print(f'\n{asset_class}')
        prices, tickers = get_stooq_prices_and_tickers(frequency=frequency, 
                                                       market=market, 
                                                       asset_class=asset_class)
        
        prices = prices.sort_index().loc[idx[:, '2000': '2023'], :]
        names = prices.index.names
        prices = (prices
                  .reset_index()
                  .drop_duplicates()
                  .set_index(names)
                  .sort_index())
        
        print('\nNo. of observations per asset')
        print(prices.groupby('ticker').size().describe())
        key = f'stooq/{market}/{asset_class.replace(" ", "/")}/'
        
        print(prices.info(show_counts=True))
        
        prices.to_hdf(DATA_STORE, key + 'prices', format='t')
        
        print(tickers.info())
        tickers.to_hdf(DATA_STORE, key + 'tickers', format='t')
# Out:
# tse stocks
# E:stooq/data/daily/jp/tse stocks
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
#
# No. of observations per asset
# count    3941.000000
# mean     3335.391525
# std      1596.491588
# min         1.000000
# 25%      2138.000000
# 50%      3977.000000
# 75%      4597.000000
# max      5881.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 13144778 entries, ('1301.JP', Timestamp('2005-03-22 00:00:00')) to ('9997.JP', Timestamp('2023-12-28 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count     Dtype
# ---  ------  --------------     -----
#  0   open    13144778 non-null  float64
#  1   high    13144778 non-null  float64
#  2   low     13144778 non-null  float64
#  3   close   13144778 non-null  float64
#  4   volume  13144778 non-null  float64
# dtypes: float64(5)
# memory usage: 551.9+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3941 entries, 0 to 3940
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  3941 non-null   object
#  1   name    3941 non-null   object
# dtypes: object(2)
# memory usage: 61.7+ KB
# None
#
# nasdaq etfs
# E:stooq/data/daily/us/nasdaq etfs
#
# No. of observations per asset
# count     355.000000
# mean     2484.377465
# std      1217.445665
# min       614.000000
# 25%      1467.500000
# 50%      2349.000000
# 75%      3341.000000
# max      6037.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 881954 entries, ('AADR.US', Timestamp('2010-07-21 00:00:00')) to ('YLDE.US', Timestamp('2023-12-29 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   open    881954 non-null  float64
#  1   high    881954 non-null  float64
#  2   low     881954 non-null  float64
#  3   close   881954 non-null  float64
#  4   volume  881954 non-null  float64
# dtypes: float64(5)
# memory usage: 37.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356 entries, 0 to 355
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  356 non-null    object
#  1   name    356 non-null    object
# dtypes: object(2)
# memory usage: 5.7+ KB
# None
#
# nasdaq stocks
# E:stooq/data/daily/us/nasdaq stocks
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# uivm.us not available
# 4500
#
# No. of observations per asset
# count    4629.000000
# mean     1792.689350
# std      1764.193013
# min         1.000000
# 25%       414.000000
# 50%       897.000000
# 75%      3069.000000
# max      6037.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8298359 entries, ('AACG.US', Timestamp('2008-01-28 00:00:00')) to ('ZZZ.US', Timestamp('2023-12-29 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    8298359 non-null  float64
#  1   high    8298359 non-null  float64
#  2   low     8298359 non-null  float64
#  3   close   8298359 non-null  float64
#  4   volume  8298359 non-null  float64
# dtypes: float64(5)
# memory usage: 348.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4669 entries, 0 to 4668
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  4669 non-null   object
#  1   name    4669 non-null   object
# dtypes: object(2)
# memory usage: 73.1+ KB
# None
#
# nyse etfs
# E:stooq/data/daily/us/nyse etfs
# 500
# 1000
# kong.us not available
# owns.us not available
# 1500
# vers.us not available
# 2000
#
# No. of observations per asset
# count    2103.000000
# mean     2146.336186
# std      1432.594528
# min        39.000000
# 25%       855.000000
# 50%      1653.000000
# 75%      3419.500000
# max      4744.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 4513745 entries, ('AAA.US', Timestamp('2020-09-11 00:00:00')) to ('ZSL.US', Timestamp('2023-12-29 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    4513745 non-null  float64
#  1   high    4513745 non-null  float64
#  2   low     4513745 non-null  float64
#  3   close   4513745 non-null  float64
#  4   volume  4513745 non-null  float64
# dtypes: float64(5)
# memory usage: 189.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2104 entries, 0 to 2103
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  2104 non-null   object
#  1   name    2104 non-null   object
# dtypes: object(2)
# memory usage: 33.0+ KB
# None
#
# nyse stocks
# E:stooq/data/daily/us/nyse stocks
# aact-u.us not available
# aact-ws.us not available
# aaic_b.us not available
# aaic_c.us not available
# achr-ws.us not available
# acro-u.us not available
# aeva-ws.us not available
# altg_a.us not available
# alur-ws.us not available
# ambp-ws.us not available
# ampx-ws.us not available
# argo_a.us not available
# armk-w.us not available
# atco_d.us not available
# atco_h.us not available
# banc_f.us not available
# bark-ws.us not available
# bbai-ws.us not available
# bfac-u.us not available
# bfac-ws.us not available
# bfly-ws.us not available
# bhil-ws.us not available
# bkkt-ws.us not available
# bksy-ws.us not available
# 500
# bnre-a.us not available
# byn-ws.us not available
# cade_a.us not available
# ccvi-u.us not available
# cdlr-w.us not available
# celg-r.us not available
# chmi_a.us not available
# chmi_b.us not available
# clbr-u.us not available
# cldt_a.us not available
# clvt_a.us not available
# cmre_b.us not available
# cmre_c.us not available
# cmre_d.us not available
# cmre_e.us not available
# cnda-u.us not available
# cnda-ws.us not available
# cndb-u.us not available
# cndb-ws.us not available
# codi_a.us not available
# codi_b.us not available
# codi_c.us not available
# corr_a.us not available
# cptk-u.us not available
# csta-u.us not available
# ctos-ws.us not available
# cubi_e.us not available
# cubi_f.us not available
# cve-ws.us not available
# cvii-u.us not available
# cvii-ws.us not available
# cwen-a.us not available
# dbrg_h.us not available
# dbrg_i.us not available
# dbrg_j.us not available
# 1000
# dlng_a.us not available
# dlng_b.us not available
# dna-ws.us not available
# dsaq-u.us not available
# dsx-ws.us not available
# eggf-u.us not available
# etwo-ws.us not available
# evex-ws.us not available
# evtl-ws.us not available
# fbrt_e.us not available
# flme-u.us not available
# flme-ws.us not available
# foa-ws.us not available
# frey-ws.us not available
# frxb-u.us not available
# gfor-u.us not available
# 1500
# glog_a.us not available
# glop_a.us not available
# glop_b.us not available
# glop_c.us not available
# gmre_a.us not available
# gpmt_a.us not available
# grbk_a.us not available
# grnd-ws.us not available
# gtls_b.us not available
# gwh-ws.us not available
# hfro_a.us not available
# hgty-ws.us not available
# hhla-u.us not available
# hipo-ws.us not available
# hlly-ws.us not available
# hyac-u.us not available
# hyac-ws.us not available
# iipr_a.us not available
# ionq-ws.us not available
# irrx-u.us not available
# irrx-ws.us not available
# irs-ws.us not available
# joby-ws.us not available
# kcgi-u.us not available
# kcgi-ws.us not available
# knsw-u.us not available
# 2000
# kref_a.us not available
# laac-w.us not available
# lanv-ws.us not available
# lev-ws-a.us not available
# lev-ws.us not available
# llap-ws.us not available
# locc-u.us not available
# lvwr-ws.us not available
# lzm-ws.us not available
# mbsc-u.us not available
# mir-ws.us not available
# mitt_a.us not available
# mitt_b.us not available
# mitt_c.us not available
# mkfg-ws.us not available
# mntn-u.us not available
# mntn-ws.us not available
# mrdb-ws.us not available
# mtal-ws.us not available
# natl-w.us not available
# ne-ws-a.us not available
# netc-u.us not available
# netc-ws.us not available
# nfys-u.us not available
# nfys-ws.us not available
# nlop-w.us not available
# note-ws.us not available
# npwr-ws.us not available
# nref_a.us not available
# nstb-ws.us not available
# 2500
# nxdt_a.us not available
# nycb_a.us not available
# nycb_u.us not available
# opfi-ws.us not available
# oust-ws.us not available
# oxy-ws.us not available
# paci-u.us not available
# perf-ws.us not available
# pgss-u.us not available
# phyt-u.us not available
# phyt-ws.us not available
# port-u.us not available
# prif_d.us not available
# prif_f.us not available
# prif_g.us not available
# prif_h.us not available
# prif_i.us not available
# prif_j.us not available
# prif_k.us not available
# prif_l.us not available
# psec_a.us not available
# psfe-ws.us not available
# psqh-ws.us not available
# qbts-ws.us not available
# rbot-ws.us not available
# rcfa-u.us not available
# rcfa-ws.us not available
# rdw-ws.us not available
# rexr_b.us not available
# rexr_c.us not available
# ritm_a.us not available
# ritm_b.us not available
# ritm_c.us not available
# ritm_d.us not available
# ross-u.us not available
# ross-ws.us not available
# rrac-u.us not available
# rrac-ws.us not available
# sbxc-ws.us not available
# 3000
# schw_d.us not available
# schw_j.us not available
# seal_a.us not available
# seal_b.us not available
# seda-u.us not available
# seda-ws.us not available
# ses-ws.us not available
# shap-ws.us not available
# sitc_a.us not available
# smr-ws.us not available
# splp_a.us not available
# spnt_b.us not available
# srvr-w.us not available
# sst-ws.us not available
# suac-u.us not available
# tcoa-u.us not available
# tcoa-ws.us not available
# trca-u.us not available
# tris-u.us not available
# tris-ws.us not available
# trtl-u.us not available
# trtl-ws.us not available
# trtn_a.us not available
# trtn_b.us not available
# trtn_c.us not available
# trtn_d.us not available
# trtn_e.us not available
# trtx_c.us not available
# uhal-b.us not available
# 3500
# uwmc-ws.us not available
# val-ws.us not available
# vln-ws.us not available
# vlto-w.us not available
# voya_b.us not available
# vst-ws-a.us not available
# vsts-w.us not available
# wbx-ws.us not available
# wel-ws.us not available
# wnnr-u.us not available
# wnnr-ws.us not available
# xflt_a.us not available
#
# No. of observations per asset
# count    3547.000000
# mean     2515.506061
# std      2028.247238
# min         1.000000
# 25%       531.000000
# 50%      2138.000000
# 75%      4743.000000
# max      6037.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8922500 entries, ('A.US', Timestamp('2000-01-03 00:00:00')) to ('ZXIET.US', Timestamp('2023-12-29 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    8922500 non-null  float64
#  1   high    8922500 non-null  float64
#  2   low     8922500 non-null  float64
#  3   close   8922500 non-null  float64
#  4   volume  8922500 non-null  float64
# dtypes: float64(5)
# memory usage: 374.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3554 entries, 0 to 3553
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  3554 non-null   object
#  1   name    3554 non-null   object
# dtypes: object(2)
# memory usage: 55.7+ KB
# None
#
# nysemkt stocks
# E:stooq/data/daily/us/nysemkt stocks
# adex-u.us not available
# adex-ws.us not available
# adrt-u.us not available
# aeon-ws.us not available
# ambi-ws.us not available
# atek-u.us not available
# atek-ws.us not available
# ault_d.us not available
# bite-u.us not available
# bite-ws.us not available
# blua-u.us not available
# blua-ws.us not available
# bmtx-ws.us not available
# buru-ws.us not available
# cldi-ws.us not available
# dmyy-u.us not available
# eliq-ws.us not available
# eve-ws.us not available
# flyx-ws.us not available
# groy-ws.us not available
# hnra-ws.us not available
# jwsm-u.us not available
# jwsm-ws.us not available
# lgl-ws.us not available
# lmnd-ws.us not available
# nstb-u.us not available
# oust-ws-a.us not available
# phge-u.us not available
# sach_a.us not available
# sbev-ws.us not available
# skyh-ws.us not available
# slnd-ws.us not available
# soar-ws.us not available
# tdw-ws.us not available
# vcxb-ws.us not available
# vhaq-r.us not available
# vhaq-u.us not available
# wrac-u.us not available
# ycbd_a.us not available
#
# No. of observations per asset
# count     319.000000
# mean     2629.968652
# std      1843.163151
# min         1.000000
# 25%       632.500000
# 50%      2602.000000
# 75%      4601.000000
# max      6035.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 838960 entries, ('AAMC.US', Timestamp('2022-03-22 00:00:00')) to ('ZOM.US', Timestamp('2023-12-29 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   open    838960 non-null  float64
#  1   high    838960 non-null  float64
#  2   low     838960 non-null  float64
#  3   close   838960 non-null  float64
#  4   volume  838960 non-null  float64
# dtypes: float64(5)
# memory usage: 35.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  319 non-null    object
#  1   name    319 non-null    object
# dtypes: object(2)
# memory usage: 5.1+ KB
# None

# %% [markdown]
# ---
